# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# ## Modern convnet architecture patterns

# %% [markdown]
# ### Modularity, hierarchy, and reuse

# %% [markdown]
# ### Residual connections

# %% [markdown]
# **Residual block where the number of filters changes**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
residual = x
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
residual = layers.Conv2D(64, 1)(residual)
x = layers.add([x, residual])

# %% [markdown]
# **Case where target block includes a max pooling layer**

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
residual = x
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
x = layers.MaxPooling2D(2, padding="same")(x)
residual = layers.Conv2D(64, 1, strides=2)(residual)
x = layers.add([x, residual])

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Rescaling(1./255)(inputs)

def residual_block(x, filters, pooling=False):
    residual = x
    x = layers.Conv2D(filters, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(filters, 3, activation="relu", padding="same")(x)
    if pooling:
        x = layers.MaxPooling2D(2, padding="same")(x)
        residual = layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
        residual = layers.Conv2D(filters, 1)(residual)
    x = layers.add([x, residual])
    return x

x = residual_block(x, filters=32, pooling=True)
x = residual_block(x, filters=64, pooling=True)
x = residual_block(x, filters=128, pooling=False)

x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  rescaling (Rescaling)          (None, 32, 32, 3)    0           ['input_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 32)   896         ['rescaling[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 32)   9248        ['conv2d_6[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)  0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 32)   128         ['rescaling[0][0]']
#
#  add_2 (Add)                    (None, 16, 16, 32)   0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 64)   18496       ['add_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 64)   36928       ['conv2d_9[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 64)    0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 64)     2112        ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 8, 8, 64)     0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 128)    73856       ['add_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 128)    147584      ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 128)    8320        ['add_3[0][0]']
#
#  add_4 (Add)                    (None, 8, 8, 128)    0           ['conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['add_4[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1)            129         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 297,697
# Trainable params: 297,697
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Batch normalization

# %% [markdown]
# ### Depthwise separable convolutions

# %% [markdown]
# ### Putting it together: A mini Xception-like model

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-05e4e9a2-24c8-48c3-816d-f947465603e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05e4e9a2-24c8-48c3-816d-f947465603e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"msoltaniehha","key":"850e83fe8c68c15d09ce24093e62d8c2"}'}

# %%
# !mkdir -pp ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c dogs-vs-cats
# !unzip -qq dogs-vs-cats.zip
# !unzip -qq train.zip
# !unzip -qq test1.zip
# Out:
# Downloading dogs-vs-cats.zip to /content
#  99% 807M/812M [00:03<00:00, 192MB/s]
# 100% 812M/812M [00:03<00:00, 269MB/s]

# %%
import os, shutil, pathlib
from tensorflow.keras.utils import image_dataset_from_directory

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)

x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=5, use_bias=False)(x)

for size in [32, 64, 128, 256, 512]:
    residual = x

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    residual = layers.Conv2D(
        size, 1, strides=2, padding="same", use_bias=False)(residual)
    x = layers.add([x, residual])

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 44s 431ms/step - loss: 0.7217 - accuracy: 0.5595 - val_loss: 0.6935 - val_accuracy: 0.5150
# Epoch 2/100
# 63/63 [==============================] - 27s 417ms/step - loss: 0.6711 - accuracy: 0.5790 - val_loss: 0.7182 - val_accuracy: 0.5000
# Epoch 3/100
# 63/63 [==============================] - 26s 404ms/step - loss: 0.6503 - accuracy: 0.6265 - val_loss: 0.7054 - val_accuracy: 0.5000
# Epoch 4/100
# 63/63 [==============================] - 25s 399ms/step - loss: 0.6364 - accuracy: 0.6335 - val_loss: 0.7021 - val_accuracy: 0.5000
# Epoch 5/100
# 63/63 [==============================] - 28s 434ms/step - loss: 0.6154 - accuracy: 0.6615 - val_loss: 0.7508 - val_accuracy: 0.5000
# Epoch 6/100
# 63/63 [==============================] - 27s 420ms/step - loss: 0.5816 - accuracy: 0.6860 - val_loss: 0.8287 - val_accuracy: 0.5000
# Epoch 7/100
# 63/63 [==============================] - 27s 423ms/step - loss: 0.5553 - accuracy: 0.7180 - val_loss: 1.0950 - val_accuracy: 0.5000
# Epoch 8/100
# 63/63 [==============================] - 27s 420ms/step - loss: 0.5421 - accuracy: 0.7350 - val_loss: 0.6340 - val_accuracy: 0.6540
# Epoch 9/100
# 63/63 [==============================] - 27s 420ms/step - loss: 0.5334 - accuracy: 0.7340 - val_loss: 0.5791 - val_accuracy: 0.7020
# Epoch 10/100
# 63/63 [==============================] - 27s 424ms/step - loss: 0.5262 - accuracy: 0.7405 - val_loss: 2.0124 - val_accuracy: 0.5210
# Epoch 11/100
# 63/63 [==============================] - 27s 419ms/step - loss: 0.5001 - accuracy: 0.7710 - val_loss: 0.5965 - val_accuracy: 0.6940
# Epoch 12/100
# 63/63 [==============================] - 27s 424ms/step - loss: 0.4970 - accuracy: 0.7660 - val_loss: 1.6491 - val_accuracy: 0.5410
# Epoch 13/100
# 63/63 [==============================] - 26s 415ms/step - loss: 0.4749 - accuracy: 0.7715 - val_loss: 2.4479 - val_accuracy: 0.5150
# Epoch 14/100
# 63/63 [==============================] - 26s 414ms/step - loss: 0.4512 - accuracy: 0.7955 - val_loss: 2.2404 - val_accuracy: 0.5500
# Epoch 15/100
# 63/63 [==============================] - 27s 420ms/step - loss: 0.4388 - accuracy: 0.8005 - val_loss: 0.9398 - val_accuracy: 0.5890
# Epoch 16/100
# 63/63 [==============================] - 26s 415ms/step - loss: 0.4344 - accuracy: 0.8090 - val_loss: 0.7253 - val_accuracy: 0.6940
# Epoch 17/100
# 63/63 [==============================] - 27s 423ms/step - loss: 0.4149 - accuracy: 0.8085 - val_loss: 0.6776 - val_accuracy: 0.6120
# Epoch 18/100
# 63/63 [==============================] - 27s 424ms/step - loss: 0.3948 - accuracy: 0.8205 - val_loss: 0.9823 - val_accuracy: 0.6840
# Epoch 19/100
# 63/63 [==============================] - 27s 419ms/step - loss: 0.4123 - accuracy: 0.8160 - val_loss: 0.5993 - val_accuracy: 0.7630
# Epoch 20/100
# 63/63 [==============================] - 26s 415ms/step - loss: 0.3993 - accuracy: 0.8280 - val_loss: 0.4096 - val_accuracy: 0.8140
# Epoch 21/100
# 63/63 [==============================] - 27s 418ms/step - loss: 0.3688 - accuracy: 0.8370 - val_loss: 0.8443 - val_accuracy: 0.6480
# Epoch 22/100
# 63/63 [==============================] - 27s 419ms/step - loss: 0.3708 - accuracy: 0.8340 - val_loss: 0.7426 - val_accuracy: 0.7290
# Epoch 23/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.3520 - accuracy: 0.8465 - val_loss: 0.7769 - val_accuracy: 0.7310
# Epoch 24/100
# 63/63 [==============================] - 26s 415ms/step - loss: 0.3357 - accuracy: 0.8515 - val_loss: 0.6565 - val_accuracy: 0.7620
# Epoch 25/100
# 63/63 [==============================] - 27s 424ms/step - loss: 0.3395 - accuracy: 0.8500 - val_loss: 0.8314 - val_accuracy: 0.7020
# Epoch 26/100
# 63/63 [==============================] - 27s 424ms/step - loss: 0.3178 - accuracy: 0.8585 - val_loss: 0.6666 - val_accuracy: 0.7100
# Epoch 27/100
# 63/63 [==============================] - 27s 425ms/step - loss: 0.3282 - accuracy: 0.8550 - val_loss: 0.8772 - val_accuracy: 0.7180
# Epoch 28/100
# 63/63 [==============================] - 27s 433ms/step - loss: 0.2883 - accuracy: 0.8765 - val_loss: 0.8188 - val_accuracy: 0.7140
# Epoch 29/100
# 63/63 [==============================] - 27s 423ms/step - loss: 0.3079 - accuracy: 0.8660 - val_loss: 0.4878 - val_accuracy: 0.8030
# Epoch 30/100
# 63/63 [==============================] - 27s 421ms/step - loss: 0.2863 - accuracy: 0.8815 - val_loss: 0.4469 - val_accuracy: 0.8120
# Epoch 31/100
# 63/63 [==============================] - 27s 420ms/step - loss: 0
100
# 63/63 [==============================] - 26s 415ms/step - loss: 0.1785 - accuracy: 0.9200 - val_loss: 1.5097 - val_accuracy: 0.6850
# Epoch 57/100
# 63/63 [==============================] - 27s 417ms/step - loss: 0.1758 - accuracy: 0.9295 - val_loss: 0.3135 - val_accuracy: 0.8800
# Epoch 58/100
# 63/63 [==============================] - 27s 427ms/step - loss: 0.1738 - accuracy: 0.9315 - val_loss: 0.3409 - val_accuracy: 0.8310
# Epoch 59/100
# 63/63 [==============================] - 27s 421ms/step - loss: 0.1599 - accuracy: 0.9365 - val_loss: 0.9959 - val_accuracy: 0.6770
# Epoch 60/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1582 - accuracy: 0.9395 - val_loss: 0.4202 - val_accuracy: 0.8610
# Epoch 61/100
# 63/63 [==============================] - 26s 412ms/step - loss: 0.1726 - accuracy: 0.9310 - val_loss: 0.3956 - val_accuracy: 0.8670
# Epoch 62/100
# 63/63 [==============================] - 27s 418ms/step - loss: 0.1616 - accuracy: 0.9380 - val_loss: 0.4581 - val_accuracy: 0.8510
# Epoch 63/100
# 63/63 [==============================] - 26s 411ms/step - loss: 0.1441 - accuracy: 0.9405 - val_loss: 0.3644 - val_accuracy: 0.8690
# Epoch 64/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1574 - accuracy: 0.9390 - val_loss: 0.4010 - val_accuracy: 0.8480
# Epoch 65/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1422 - accuracy: 0.9470 - val_loss: 0.9272 - val_accuracy: 0.7350
# Epoch 66/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1355 - accuracy: 0.9495 - val_loss: 0.3686 - val_accuracy: 0.8560
# Epoch 67/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1428 - accuracy: 0.9440 - val_loss: 0.3192 - val_accuracy: 0.8660
# Epoch 68/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1588 - accuracy: 0.9345 - val_loss: 0.3640 - val_accuracy: 0.8970
# Epoch 69/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1518 - accuracy: 0.9410 - val_loss: 0.5244 - val_accuracy: 0.8210
# Epoch 70/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1388 - accuracy: 0.9520 - val_loss: 0.7933 - val_accuracy: 0.7920
# Epoch 71/100
# 63/63 [==============================] - 27s 419ms/step - loss: 0.1331 - accuracy: 0.9485 - val_loss: 0.3704 - val_accuracy: 0.8700
# Epoch 72/100
# 63/63 [==============================] - 27s 426ms/step - loss: 0.1303 - accuracy: 0.9525 - val_loss: 0.4507 - val_accuracy: 0.8810
# Epoch 73/100
# 63/63 [==============================] - 27s 425ms/step - loss: 0.1408 - accuracy: 0.9410 - val_loss: 0.9842 - val_accuracy: 0.7420
# Epoch 74/100
# 63/63 [==============================] - 27s 420ms/step - loss: 0.1331 - accuracy: 0.9475 - val_loss: 0.3815 - val_accuracy: 0.8720
# Epoch 75/100
# 63/63 [==============================] - 26s 416ms/step - loss: 0.1290 - accuracy: 0.9450 - val_loss: 0.3555 - val_accuracy: 0.8820
# Epoch 76/100
# 63/63 [==============================] - 27s 417ms/step - loss: 0.1338 - accuracy: 0.9445 - val_loss: 0.3887 - val_accuracy: 0.8630
# Epoch 77/100
# 63/63 [==============================] - 27s 416ms/step - loss: 0.1234 - accuracy: 0.9470 - val_loss: 0.5166 - val_accuracy: 0.8690
# Epoch 78/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1315 - accuracy: 0.9510 - val_loss: 0.3700 - val_accuracy: 0.8640
# Epoch 79/100
# 63/63 [==============================] - 26s 413ms/step - loss: 0.1362 - accuracy: 0.9440 - val_loss: 0.5768 - val_accuracy: 0.8240
# Epoch 80/100
# 63/63 [==============================] - 27s 418ms/step - loss: 0.1212 - accuracy: 0.9520 - val_loss: 0.3609 - val_accuracy: 0.8840
# Epoch 81/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1088 - accuracy: 0.9610 - val_loss: 0.3185 - val_accuracy: 0.8990
# Epoch 82/100
# 63/63 [==============================] - 26s 414ms/step - loss: 0.1161 - accuracy: 0.9540 - val_loss: 0.3497 - val_accuracy: 0.8800
# Epoch 83/100
# 63/63 [==============================] - 27s 419ms/step - loss: 0.1345 - accuracy: 0.9470 - val_loss: 0.5918 - val_accuracy: 0.8330
# Epoch 84/100
# 63/63 [==============================] - 27s 423ms/step - loss: 0.1047 - accuracy: 0.9570 - val_loss: 0.3600 - val_accuracy: 0.8730
# Epoch 85/100
# 63/63 [==============================] - 26s 415ms/step - loss: 0.1140 - accuracy: 0.9555 - val_loss: 1.4337 - val_accuracy: 0.7590
# Epoch 86/100
# 63/63 [==============================] - 27s 423ms/step - loss: 0.1292 - accuracy: 0.9535 - val_loss: 0.3011 - val_accuracy: 0.9150
# Epoch 87/100
# 63/63 [==============================] - 27s 420ms/step - loss: 0.1124 - accuracy: 0.9600 - val_loss: 0.4978 - val_accuracy: 0.8450
# Epoch 88/100
# 63/63 [==============================] - 27s 421ms/step - loss: 0.1133 - accuracy: 0.9560 - val_loss: 0.4435 - val_accuracy: 0.8820
# Epoch 89/100
# 63/63 [==============================] - 27s 418ms/step - loss: 0.1126 - accuracy: 0.9595 - val_loss: 0.3797 - val_accuracy: 0.8820
# Epoch 90/100
# 63/63 [==============================] - 27s 420ms/step - loss: 0.0941 - accuracy: 0.9675 - val_loss: 0.3351 - val_accuracy: 0.8750
# Epoch 91/100
# 63/63 [==============================] - 26s 417ms/step - loss: 0.1214 - accuracy: 0.9455 - val_loss: 0.3897 - val_accuracy: 0.8910
# Epoch 92/100
# 63/63 [==============================] - 27s 421ms/step - loss: 0.1049 - accuracy: 0.9595 - val_loss: 0.5263 - val_accuracy: 0.8760
# Epoch 93/100
# 63/63 [==============================] - 27s 421ms/step - loss: 0.1073 - accuracy: 0.9540 - val_loss: 0.3824 - val_accuracy: 0.8870
# Epoch 94/100
# 63/63 [==============================] - 27s 420ms/step - loss: 0.1137 - accuracy: 0.9575 - val_loss: 1.2722 - val_accuracy: 0.7260
# Epoch 95/100
# 63/63 [==============================] - 27s 422ms/step - loss: 0.1075 - accuracy: 0.9595 - val_loss: 1.2596 - val_accuracy: 0.7510
# Epoch 96/100
# 63/63 [==============================] - 27s 421ms/step - loss: 0.0923 - accuracy: 0.9655 - val_loss: 0.6230 - val_accuracy: 0.8430
# Epoch 97/100
# 63/63 [==============================] - 27s 424ms/step - loss: 0.1103 - accuracy: 0.9605 - val_loss: 0.3846 - val_accuracy: 0.8810
# Epoch 98/100
# 63/63 [==============================] - 27s 423ms/step - loss: 0.1142 - accuracy: 0.9620 - val_loss: 0.3280 - val_accuracy: 0.8850
# Epoch 99/100
# 63/63 [==============================] - 27s 421ms/step - loss: 0.0901 - accuracy: 0.9685 - val_loss: 0.4937 - val_accuracy: 0.8920
# Epoch 100/100
# 63/63 [==============================] - 26s 415ms/step - loss: 0.0820 - accuracy: 0.9640 - val_loss: 0.5045 - val_accuracy: 0.8630

# %%
import matplotlib.pyplot as plt
loss_values = history.history["accuracy"]
val_loss_values = history.history["val_accuracy"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training accuracy")
plt.plot(epochs, val_loss_values, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.legend();

# %%
loss_values = history.history["loss"]
val_loss_values = history.history["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend();

# %% [markdown]
# Our new model achieves a test accuracy of 90.8%, compared to 83.5% for the naive model in the last chapter.
