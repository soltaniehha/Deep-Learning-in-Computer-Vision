# %% [markdown]
# <a href="https://colab.research.google.com/github/soltaniehha/Deep-Learning-in-Computer-Vision/blob/master/29-Deep-Dream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Dream
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2016/01/13<br>
# **Last modified:** 2020/05/02<br>
# **Description:** Generating Deep Dreams with Keras.

# %% [markdown]
# ## Introduction
#
# "Deep dream" is an image-filtering technique which consists of taking an image
# classification model, and running gradient ascent over an input image to
# try to maximize the activations of specific layers (and sometimes, specific units in
# specific layers) for this input. It produces hallucination-like visuals.
#
# It was first introduced by Alexander Mordvintsev from Google in July 2015.
#
# Process:
#
# - Load the original image.
# - Define a number of processing scales ("octaves"),
# from smallest to largest.
# - Resize the original image to the smallest scale.
# - For every scale, starting with the smallest (i.e. current one):
#     - Run gradient ascent
#     - Upscale image to the next scale
#     - Reinject the detail that was lost at upscaling time
# - Stop when we are back to the original size.
# To obtain the detail lost during upscaling, we simply
# take the original image, shrink it down, upscale it,
# and compare the result to the (resized) original image.

# %% [markdown]
# ## What is Deep Dream?

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('f23vEzI3LQ0', width=400, height=300)

# %% [markdown]
# ## Journey on the Deep Dream
#
# An example work created by a deep dream algorithm.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('SCE-QeDfXtA', width=400, height=300)

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import inception_v3

base_image_path = keras.utils.get_file("original.jpg",
                                       "http://www.reidsitaly.com/site/assets/files/3147/pablo-picasso-self-portraits-over-the-years.-toppic.jpg")
result_prefix = "dreamed"

# These are the names of the layers
# for which we try to maximize activation,
# as well as their weight in the final loss
# we try to maximize.
# You can tweak these setting to obtain new visual effects.
layer_settings = {
    "mixed4": 2.0,
    "mixed5": 2.5,
    "mixed6": 3.0,
    "mixed7": 5,
}

# Playing with these hyperparameters will also allow you to achieve new effects
step = 0.01  # Gradient ascent step size
num_octave = 5  # Number of scales at which to run gradient ascent
octave_scale = 1.4  # Size ratio between scales
iterations = 100  # Number of ascent steps per scale
max_loss = 25.0

# %% [markdown]
# This is our base image:

# %%
from IPython.display import Image, display

display(Image(base_image_path, width = 600, height = 300))

# %% [markdown]
# Let's set up some image preprocessing/deprocessing utilities:

# %%
def preprocess_image(image_path):
    # Util function to open, resize and format pictures
    # into appropriate arrays.
    img = keras.preprocessing.image.load_img(image_path)
    img = keras.preprocessing.image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = inception_v3.preprocess_input(img)
    return img


def deprocess_image(x):
    # Util function to convert a NumPy array into a valid image.
    x = x.reshape((x.shape[1], x.shape[2], 3))
    # Undo inception v3 preprocessing
    x /= 2.0
    x += 0.5
    x *= 255.0
    # Convert to uint8 and clip to the valid range [0, 255]
    x = np.clip(x, 0, 255).astype("uint8")
    return x

# %% [markdown]
# ## Compute the Deep Dream loss
#
# First, build a feature extraction model to retrieve the activations of our target layers
# given an input image.

# %%
# Build an InceptionV3 model loaded with pre-trained ImageNet weights
model = inception_v3.InceptionV3(weights="imagenet", include_top=False)

# Get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict(
    [
        (layer.name, layer.output)
        for layer in [model.get_layer(name) for name in layer_settings.keys()]
    ]
)

# Set up a model that returns the activation values for every target layer
# (as a dict)
feature_extractor = keras.Model(inputs=model.inputs, outputs=outputs_dict)

# %% [markdown]
# The actual loss computation is very simple:

# %%
def compute_loss(input_image):
    features = feature_extractor(input_image)
    # Initialize the loss
    loss = tf.zeros(shape=())
    for name in features.keys():
        coeff = layer_settings[name]
        activation = features[name]
        # We avoid border artifacts by only involving non-border pixels in the loss.
        scaling = tf.reduce_prod(tf.cast(tf.shape(activation), "float32"))
        loss += coeff * tf.reduce_sum(tf.square(activation[:, 2:-2, 2:-2, :])) / scaling
    return loss

# %% [markdown]
# ## Set up the gradient ascent loop for one octave

# %%
@tf.function
def gradient_ascent_step(img, learning_rate):
    with tf.GradientTape() as tape:
        tape.watch(img)
        loss = compute_loss(img)
    # Compute gradients.
    grads = tape.gradient(loss, img)
    # Normalize gradients.
    grads /= tf.maximum(tf.reduce_mean(tf.abs(grads)), 1e-6)
    img += learning_rate * grads
    return loss, img


def gradient_ascent_loop(img, iterations, learning_rate, max_loss=None):
    for i in range(iterations):
        loss, img = gradient_ascent_step(img, learning_rate)
        if max_loss is not None and loss > max_loss:
            break
        print("... Loss value at step %d: %.2f" % (i, loss))
    return img

# %% [markdown]
# ## Run the training loop, iterating over different octaves

# %%
original_img = preprocess_image(base_image_path)
original_shape = original_img.shape[1:3]

successive_shapes = [original_shape]
for i in range(1, num_octave):
    shape = tuple([int(dim / (octave_scale ** i)) for dim in original_shape])
    successive_shapes.append(shape)
successive_shapes = successive_shapes[::-1]
shrunk_original_img = tf.image.resize(original_img, successive_shapes[0])

img = tf.identity(original_img)  # Make a copy
for i, shape in enumerate(successive_shapes):
    print("Processing octave %d with shape %s" % (i, shape))
    img = tf.image.resize(img, shape)
    img = gradient_ascent_loop(
        img, iterations=iterations, learning_rate=step, max_loss=max_loss
    )
    upscaled_shrunk_original_img = tf.image.resize(shrunk_original_img, shape)
    same_size_original = tf.image.resize(original_img, shape)
    lost_detail = same_size_original - upscaled_shrunk_original_img

    img += lost_detail
    shrunk_original_img = tf.image.resize(original_img, shape)

keras.preprocessing.image.save_img(result_prefix + ".png", deprocess_image(img.numpy()))
# Out:
# Processing octave 0 with shape (156, 312)
# ... Loss value at step 0: 0.86
# ... Loss value at step 1: 1.27
# ... Loss value at step 2: 1.69
# ... Loss value at step 3: 2.18
# ... Loss value at step 4: 2.70
# ... Loss value at step 5: 3.01
# ... Loss value at step 6: 3.34
# ... Loss value at step 7: 3.73
# ... Loss value at step 8: 4.33
# ... Loss value at step 9: 4.63
# ... Loss value at step 10: 5.18
# ... Loss value at step 11: 5.14
# ... Loss value at step 12: 5.82
# ... Loss value at step 13: 6.28
# ... Loss value at step 14: 6.45
# ... Loss value at step 15: 6.99
# ... Loss value at step 16: 7.47
# ... Loss value at step 17: 8.08
# ... Loss value at step 18: 8.17
# ... Loss value at step 19: 9.05
# ... Loss value at step 20: 9.57
# ... Loss value at step 21: 9.88
# ... Loss value at step 22: 10.20
# ... Loss value at step 23: 10.46
# ... Loss value at step 24: 10.90
# ... Loss value at step 25: 11.40
# ... Loss value at step 26: 12.10
# ... Loss value at step 27: 13.11
# ... Loss value at step 28: 12.56
# ... Loss value at step 29: 13.60
# ... Loss value at step 30: 13.55
# ... Loss value at step 31: 14.26
# ... Loss value at step 32: 13.81
# ... Loss value at step 33: 14.82
# ... Loss value at step 34: 15.06
# ... Loss value at step 35: 15.81
# ... Loss value at step 36: 16.47
# ... Loss value at step 37: 17.15
# ... Loss value at step 38: 17.54
# ... Loss value at step 39: 18.10
# ... Loss value at step 40: 18.30
# ... Loss value at step 41: 17.20
# ... Loss value at step 42: 19.22
# ... Loss value at step 43: 19.78
# ... Loss value at step 44: 19.19
# ... Loss value at step 45: 19.63
# ... Loss value at step 46: 20.71
# ... Loss value at step 47: 21.24
# ... Loss value at step 48: 20.90
# ... Loss value at step 49: 22.21
# ... Loss value at step 50: 22.21
# ... Loss value at step 51: 23.04
# ... Loss value at step 52: 23.47
# ... Loss value at step 53: 24.55
# ... Loss value at step 54: 23.03
# ... Loss value at step 55: 23.97
# Processing octave 1 with shape (218, 437)
# ... Loss value at step 0: 1.27
# ... Loss value at step 1: 1.96
# ... Loss value at step 2: 2.79
# ... Loss value at step 3: 3.12
# ... Loss value at step 4: 3.94
# ... Loss value at step 5: 4.49
# ... Loss value at step 6: 5.28
# ... Loss value at step 7: 5.25
# ... Loss value at step 8: 6.19
# ... Loss value at step 9: 6.53
# ... Loss value at step 10: 7.61
# ... Loss value at step 11: 8.35
# ... Loss value at step 12: 8.99
# ... Loss value at step 13: 8.77
# ... Loss value at step 14: 10.14
# ... Loss value at step 15: 10.23
# ... Loss value at step 16: 10.32
# ... Loss value at step 17: 11.03
# ... Loss value at step 18: 12.08
# ... Loss value at step 19: 12.22
# ... Loss value at step 20: 13.07
# ... Loss value at step 21: 13.72
# ... Loss value at step 22: 14.15
# ... Loss value at step 23: 14.68
# ... Loss value at step 24: 15.27
# ... Loss value at step 25: 16.03
# ... Loss value at step 26: 16.59
# ... Loss value at step 27: 17.62
# ... Loss value at step 28: 17.07
# ... Loss value at step 29: 18.40
# ... Loss value at step 30: 18.33
# ... Loss value at step 31: 18.80
# ... Loss value at step 32: 20.25
# ... Loss value at step 33: 20.53
# ... Loss value at step 34: 20.28
# ... Loss value at step 35: 20.94
# ... Loss value at step 36: 22.15
# ... Loss value at step 37: 22.90
# ... Loss value at step 38: 23.54
# ... Loss value at step 39: 22.77
# ... Loss value at step 40: 23.27
# ... Loss value at step 41: 24.12
# ... Loss value at step 42: 24.65
# Processing octave 2 with shape (306, 612)
# ... Loss value at step 0: 1.23
# ... Loss value at step 1: 1.87
# ... Loss value at step 2: 2.40
# ... Loss value at step 3: 2.61
# ... Loss value at step 4: 3.05
# ... Loss value at step 5: 3.41
# ... Loss value at step 6: 4.00
# ... Loss value at step 7: 4.97
# ... Loss value at step 8: 5.61
# ... Loss value at step 9: 5.83
# ... Loss value at step 10: 6.07
# ... Loss value at step 11: 6.42
# ... Loss value at step 12: 6.65
# ... Loss value at step 13: 6.87
# ... Loss value at step 14: 7.95
# ... Loss value at step 15: 8.14
# ... Loss value at step 16: 8.71
# ... Loss value at step 17: 9.18
# ... Loss value at step 18: 9.28
# ... Loss value at step 19: 9.69
# ... Loss value at step 20: 10.78
# ... Loss value at step 21: 11.51
# ... Loss value at step 22: 11.81
# ... Loss value at step 23: 12.09
# ... Loss value at step 24: 12.64
# ... Loss value at step 25: 12.95
# ... Loss value at step 26: 13.99
# ... Loss value at step 27: 14.14
# ... Loss value at step 28: 14.58
# ... Loss value at step 29: 15.09
# ... Loss value at step 30: 15.25
# ... Loss value at step 31: 15.48
# ... Loss value at step 32: 16.07
# ... Loss value at step 33: 16.00
# ... Loss value at step 34: 16.21
# ... Loss value at step 35: 17.85
# ... Loss value at step 36: 18.16
# ... Loss value at step 37: 18.16
# ... Loss value at step 38: 18.26
# ... Loss value at step 39: 19.81
# ... Loss value at step 40: 19.29
# ... Loss value at step 41: 21.32
# ... Loss value at step 42: 20.66
# ... Loss value at step 43: 20.60
# ... Loss value at step 44: 20.82
# ... Loss value at step 45: 21.67
# ... Loss value at step 46: 21.48
# ... Loss value at step 47: 22.93
# ... Loss value at step 48: 22.48
# ... Loss value at step 49: 24.03
# ... Loss value at step 50: 23.26
# ... Loss value at step 51: 24.24
# ... Loss value at step 52: 24.74
# Processing octave 3 with shape (428, 857)
# ... Loss value at step 0: 1.27
# ... Loss value at step 1: 1.85
# ... Loss value at step 2: 2.44
# ... Loss value at step 3: 2.92
# ... Loss value at step 4: 3.35
# ... Loss value at step 5: 3.84
# ... Loss value at step 6: 4.23
# ... Loss value at step 7: 4.42
# ... Loss value at step 8: 4.84
# ... Loss value at step 9: 5.38
# ... Loss value at step 10: 6.01
# ... Loss value at step 11: 6.34
# ... Loss value at step 12: 6.50
# ... Loss value at step 13: 6.72
# ... Loss value at step 14: 7.43
# ... Loss value at step 15: 8.00
# ... Loss value at step 16: 8.18
# ... Loss value at step 17: 8.97
# ... Loss value at step 18: 8.74
# ... Loss value at step 19: 8.71
# ... Loss value at step 20: 9.95
# ... Loss value at step 21: 10.39
# ... Loss value at step 22: 11.28
# ... Loss value at step 23: 11.60
# ... Loss value at step 24: 12.32
# ... Loss value at step 25: 12.52
# ... Loss value at step 26: 12.86
# ... Loss value at step 27: 13.04
# ... Loss value at step 28: 12.43
# ... Loss value at step 29: 13.83
# ... Loss value at step 30: 14.83
# ... Loss value at step 31: 14.39
# ... Loss value at step 32: 15.08
# ... Loss value at step 33: 15.82
# ... Loss value at step 34: 16.41
# ... Loss value at step 35: 16.04
# ... Loss value at step 36: 16.44
# ... Loss value at step 37: 17.21
# ... Loss value at step 38: 16.99
# ... Loss value at step 39: 16.95
# ... Loss value at step 40: 17.73
# ... Loss value at step 41: 17.85
# ... Loss value at step 42: 18.45
# ... Loss value at step 43: 18.61
# ... Loss value at step 44: 19.44
# ... Loss value at step 45: 19.92
# ... Loss value at step 46: 20.47
# ... Loss value at step 47: 21.16
# ... Loss value at step 48: 21.42
# ... Loss value at step 49: 21.40
# ... Loss value at step 50: 21.95
# ... Loss value at step 51: 22.75
# ... Loss value at step 52: 22.97
# ... Loss value at step 53: 23.15
# ... Loss value at step 54: 23.31
# ... Loss value at step 55: 23.09
# ... Loss value at step 56: 24.25
# ... Loss value at step 57: 24.03
# ... Loss value at step 58: 24.37
# ... Loss value at step 59: 23.75
# Processing octave 4 with shape (600, 1200)
# ... Loss value at step 0: 1.44
# ... Loss value at step 1: 2.34
# ... Loss value at step 2: 3.61
# ... Loss value at step 3: 5.07
# ... Loss value at step 4: 7.09
# ... Loss value at step 5: 10.56
# ... Loss value at step 6: 15.19
# ... Loss value at step 7: 24.09

# %% [markdown]
# Display the result.

# %%
# Original image
display(Image(base_image_path, width = 600, height = 300))

# %%
# Transformed
display(Image(result_prefix + ".png", width = 600, height = 300))
