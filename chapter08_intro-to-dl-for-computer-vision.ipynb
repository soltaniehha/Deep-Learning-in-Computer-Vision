# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Introduction to deep learning for computer vision

# %% [markdown]
# ## Introduction to convnets

# %% [markdown]
# **Instantiating a small convnet**

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# **Displaying the model's summary**

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 10)                11530
#
# =================================================================
# Total params: 104,202
# Trainable params: 104,202
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Training the convnet on MNIST images**

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Epoch 1/5
# 938/938 [==============================] - 20s 5ms/step - loss: 0.1563 - accuracy: 0.9517
# Epoch 2/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0445 - accuracy: 0.9864
# Epoch 3/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0312 - accuracy: 0.9902
# Epoch 4/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0240 - accuracy: 0.9927
# Epoch 5/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0175 - accuracy: 0.9947

# %% [markdown]
# **Evaluating the convnet**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0229 - accuracy: 0.9930
# Test accuracy: 0.993

# %% [markdown]
# ### The convolution operation

# %% [markdown]
# #### Understanding border effects and padding

# %% [markdown]
# #### Understanding convolution strides

# %% [markdown]
# ### The max-pooling operation

# %% [markdown]
# **An incorrectly structured convnet missing its max-pooling layers**

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 22, 22, 128)       73856
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_1 (Dense)             (None, 10)                619530
#
# =================================================================
# Total params: 712,202
# Trainable params: 712,202
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training a convnet from scratch on a small dataset

# %% [markdown]
# ### The relevance of deep learning for small-data problems

# %% [markdown]
# ### Downloading the data
# [Dogs vs. Cats Kaggle competition](https://www.kaggle.com/c/dogs-vs-cats/data)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cd9278e4-f1d3-4099-b24d-f557d764a90e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd9278e4-f1d3-4099-b24d-f557d764a90e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"msoltaniehha","key":"44c8dfccb7b1b7f4091f5ac416b89d2a"}'}

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Downloading dogs-vs-cats.zip to /content
#  99% 805M/812M [00:11<00:00, 61.0MB/s]
# 100% 812M/812M [00:11<00:00, 71.2MB/s]

# %%
# !unzip -qq dogs-vs-cats.zip

# %%
# !unzip -qq train.zip

# %%
# !unzip -qq test1.zip

# %%
train_files = !ls -l train

# %%
import matplotlib.pyplot as plt
import os
import random

train_files = os.listdir('train')
sample_images = random.sample(train_files, 100)

fig, axes = plt.subplots(4, 4, figsize=(8, 8),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.4))

for i, ax in enumerate(axes.flat):
    ax.imshow(Image.open('train/'+sample_images[i]).resize((180, 180)))
    ax.set_title(sample_images[i])

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_5 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 256)         590080
#
#  flatten_2 (Flatten)         (None, 12544)             0
#
#  dense_2 (Dense)             (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Fitting the model using a `Dataset`**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 7s 80ms/step - loss: 0.7161 - accuracy: 0.5115 - val_loss: 0.6881 - val_accuracy: 0.6210
# Epoch 2/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.7695 - accuracy: 0.5795 - val_loss: 0.8554 - val_accuracy: 0.5140
# Epoch 3/30
# 63/63 [==============================] - 5s 68ms/step - loss: 0.6652 - accuracy: 0.6430 - val_loss: 0.6262 - val_accuracy: 0.6420
# Epoch 4/30
# 63/63 [==============================] - 4s 66ms/step - loss: 0.6457 - accuracy: 0.6560 - val_loss: 0.6455 - val_accuracy: 0.6290
# Epoch 5/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.5887 - accuracy: 0.6845 - val_loss: 0.6475 - val_accuracy: 0.6370
# Epoch 6/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.5587 - accuracy: 0.7195 - val_loss: 0.5631 - val_accuracy: 0.7050
# Epoch 7/30
# 63/63 [==============================] - 6s 86ms/step - loss: 0.5184 - accuracy: 0.7375 - val_loss: 0.5996 - val_accuracy: 0.6840
# Epoch 8/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.4694 - accuracy: 0.7715 - val_loss: 0.6960 - val_accuracy: 0.7070
# Epoch 9/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.4419 - accuracy: 0.7970 - val_loss: 0.7162 - val_accuracy: 0.6820
# Epoch 10/30
# 63/63 [==============================] - 5s 81ms/step - loss: 0.3651 - accuracy: 0.8320 - val_loss: 0.7166 - val_accuracy: 0.6870
# Epoch 11/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.3249 - accuracy: 0.8630 - val_loss: 0.6969 - val_accuracy: 0.7410
# Epoch 12/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.3168 - accuracy: 0.8805 - val_loss: 0.6591 - val_accuracy: 0.7490
# Epoch 13/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.2275 - accuracy: 0.9015 - val_loss: 0.7271 - val_accuracy: 0.7330
# Epoch 14/30
keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 3s 35ms/step - loss: 0.5718 - accuracy: 0.7110
# Test accuracy: 0.711

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **Training the regularized convnet**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 6s 74ms/step - loss: 0.7451 - accuracy: 0.5055 - val_loss: 0.6908 - val_accuracy: 0.6340
# Epoch 2/100
# 63/63 [==============================] - 5s 70ms/step - loss: 0.6993 - accuracy: 0.5410 - val_loss: 0.8377 - val_accuracy: 0.5000
# Epoch 3/100
# 63/63 [==============================] - 5s 71ms/step - loss: 0.6945 - accuracy: 0.5595 - val_loss: 0.6796 - val_accuracy: 0.5720
# Epoch 4/100
# 63/63 [==============================] - 5s 75ms/step - loss: 0.6659 - accuracy: 0.6290 - val_loss: 0.6332 - val_accuracy: 0.6480
# Epoch 5/100
# 63/63 [==============================] - 6s 88ms/step - loss: 0.6516 - accuracy: 0.6390 - val_loss: 0.6219 - val_accuracy: 0.6380
# Epoch 6/100
# 63/63 [==============================] - 5s 71ms/step - loss: 0.6240 - accuracy: 0.6640 - val_loss: 0.5919 - val_accuracy: 0.6910
# Epoch 7/100
# 63/63 [==============================] - 5s 71ms/step - loss: 0.6009 - accuracy: 0.6775 - val_loss: 0.6061 - val_accuracy: 0.6640
# Epoch 8/100
# 63/63 [==============================] - 5s 72ms/step - loss: 0.5895 - accuracy: 0.7020 - val_loss: 0.6280 - val_accuracy: 0.6730
# Epoch 9/100
# 63/63 [==============================] - 5s 72ms/step - loss: 0.5737 - accuracy: 0.7155 - val_loss: 0.7243 - val_accuracy: 0.5690
# Epoch 10/100
# 63/63 [==============================] - 5s 74ms/step - loss: 0.5635 - accuracy: 0.7125 - val_loss: 0.6998 - val_accuracy: 0.6110
# Epoch 11/100
# 63/63 [==============================] - 5s 71ms/step - loss: 0.5648 - accuracy: 0.7065 - val_loss: 0.5742 - val_accuracy: 0.6900
# Epoch 12/100
# 63/63 [==============================] - 5s 73ms/step - loss: 0.5351 - accuracy: 0.7385 - val_loss: 0.5358 - val_accuracy: 0.7190
# Epoch 13/100
# 63/63 [==============================] - 5s 72ms/step - loss: 0.5224 - accuracy: 0.7275 - val_loss: 0.5387 - val_accuracy: 0.7270
# Epoch 14/100
# 63/63 [==============================] - 5s 73ms/step - loss: 0.5283 - accuracy: 0.7310 - val_loss: 0.5050 - val_accuracy: 0.7400
# Epoch 15/100
# 63/63 [==============================] - 5s 70ms/step - loss: 0.1598 - accuracy: 0.9430 - val_loss: 2.0470 - val_accuracy: 0.7780
# Epoch 92/100
# 63/63 [==============================] - 5s 71ms/step - loss: 0.2008 - accuracy: 0.9340 - val_loss: 0.5242 - val_accuracy: 0.8320
# Epoch 93/100
# 63/63 [==============================] - 5s 69ms/step - loss: 0.1634 - accuracy: 0.9460 - val_loss: 1.3888 - val_accuracy: 0.8200
# Epoch 94/100
# 63/63 [==============================] - 5s 70ms/step - loss: 0.1944 - accuracy: 0.9325 - val_loss: 0.6899 - val_accuracy: 0.8150
# Epoch 95/100
# 63/63 [==============================] - 5s 70ms/step - loss: 0.1751 - accuracy: 0.9355 - val_loss: 1.2946 - val_accuracy: 0.7970
# Epoch 96/100
# 63/63 [==============================] - 5s 69ms/step - loss: 0.1848 - accuracy: 0.9330 - val_loss: 0.7879 - val_accuracy: 0.8370
# Epoch 97/100
# 63/63 [==============================] - 5s 70ms/step - loss: 0.1861 - accuracy: 0.9355 - val_loss: 1.0600 - val_accuracy: 0.8240
# Epoch 98/100
# 63/63 [==============================] - 5s 71ms/step - loss: 0.1956 - accuracy: 0.9330 - val_loss: 0.6491 - val_accuracy: 0.8460
# Epoch 99/100
# 63/63 [==============================] - 5s 71ms/step - loss: 0.1811 - accuracy: 0.9370 - val_loss: 1.0563 - val_accuracy: 0.8050
# Epoch 100/100
# 63/63 [==============================] - 5s 70ms/step - loss: 0.1919 - accuracy: 0.9340 - val_loss: 0.7376 - val_accuracy: 0.8460

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 3s 35ms/step - loss: 0.4512 - accuracy: 0.8225
# Test accuracy: 0.822

# %% [markdown]
# ## Leveraging a pretrained model

# %% [markdown]
# ### Feature extraction with a pretrained model

# %% [markdown]
# **Instantiating the VGG16 convolutional base**

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Fast feature extraction without data augmentation

# %% [markdown]
# **Extracting the VGG16 features and corresponding labels**

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)

# %%
train_features.shape
# Out:
# (2000, 5, 5, 512)

# %% [markdown]
# **Defining and training the densely connected classifier**

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
      filepath="feature_extraction.keras",
      save_best_only=True,
      monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 9ms/step - loss: 21.4938 - accuracy: 0.9305 - val_loss: 2.8411 - val_accuracy: 0.9710
# Epoch 2/20
# 63/63 [==============================] - 0s 7ms/step - loss: 3.9071 - accuracy: 0.9735 - val_loss: 8.4208 - val_accuracy: 0.9480
# Epoch 3/20
# 63/63 [==============================] - 0s 7ms/step - loss: 2.0704 - accuracy: 0.9875 - val_loss: 4.0404 - val_accuracy: 0.9780
# Epoch 4/20
# 63/63 [==============================] - 0s 7ms/step - loss: 2.6941 - accuracy: 0.9825 - val_loss: 5.1953 - val_accuracy: 0.9660
# Epoch 5/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.4661 - accuracy: 0.9950 - val_loss: 4.2035 - val_accuracy: 0.9730
# Epoch 6/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.8843 - accuracy: 0.9945 - val_loss: 5.3919 - val_accuracy: 0.9740
# Epoch 7/20
# 63/63 [==============================] - 0s 6ms/step - loss: 1.0183 - accuracy: 0.9950 - val_loss: 7.8023 - val_accuracy: 0.9600
# Epoch 8/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.3110 - accuracy: 0.9970 - val_loss: 5.8653 - val_accuracy: 0.9640
# Epoch 9/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.3904 - accuracy: 0.9950 - val_loss: 6.5223 - val_accuracy: 0.9700
# Epoch 10/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.8083 - accuracy: 0.9945 - val_loss: 5.9445 - val_accuracy: 0.9720
# Epoch 11/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2412 - accuracy: 0.9975 - val_loss: 7.7565 - val_accuracy: 0.9720
# Epoch 12/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1973 - accuracy: 0.9965 - val_loss: 5.4542 - val_accuracy: 0.9690
# Epoch 13/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1517 - accuracy: 0.9985 - val_loss: 8.4771 - val_accuracy: 0.9710
# Epoch 14/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0403 - accuracy: 0.9990 - val_loss: 12.2475 - val_accuracy: 0.9660
# Epoch 15/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0499 - accuracy: 0.9985 - val_loss: 5.5993 - val_accuracy: 0.9750
# Epoch 16/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.3641 - accuracy: 0.9975 - val_loss: 7.7637 - val_accuracy: 0.9720
# Epoch 17/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0135 - accuracy: 0.9995 - val_loss: 7.0583 - val_accuracy: 0.9710
# Epoch 18/20
# 63/63 [==============================] - 0s 6ms/step - loss: 5.5263e-04 - accuracy: 0.9995 - val_loss: 6.7001 - val_accuracy: 0.9690
# Epoch 19/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0603 - accuracy: 0.9985 - val_loss: 7.6890 - val_accuracy: 0.9680
# Epoch 20/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2511 - accuracy: 0.9980 - val_loss: 5.4248 - val_accuracy: 0.9720

# %% [markdown]
# **Plotting the results**

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# #### Feature extraction together with data augmentation

# %% [markdown]
# **Instantiating and freezing the VGG16 convolutional base**

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False

# %% [markdown]
# **Printing the list of trainable weights before and after freezing**

# %%
conv_base.trainable = True
print("This is the number of trainable weights "
      "before freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights before freezing the conv base: 26

# %%
conv_base.trainable = False
print("This is the number of trainable weights "
      "after freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights after freezing the conv base: 0

# %% [markdown]
# **Adding a data augmentation stage and a classifier to the convolutional base**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 13s 186ms/step - loss: 17.2518 - accuracy: 0.8995 - val_loss: 3.5577 - val_accuracy: 0.9700
# Epoch 2/50
# 63/63 [==============================] - 12s 188ms/step - loss: 6.2565 - accuracy: 0.9445 - val_loss: 2.9512 - val_accuracy: 0.9780
# Epoch 3/50
# 63/63 [==============================] - 12s 185ms/step - loss: 6.2585 - accuracy: 0.9485 - val_loss: 16.2670 - val_accuracy: 0.9290
# Epoch 4/50
# 63/63 [==============================] - 12s 184ms/step - loss: 6.3227 - accuracy: 0.9595 - val_loss: 3.9852 - val_accuracy: 0.9780
# Epoch 5/50
# 63/63 [==============================] - 12s 180ms/step - loss: 5.5414 - accuracy: 0.9630 - val_loss: 3.9823 - val_accuracy: 0.9760
# Epoch 6/50
# 63/63 [==============================] - 12s 182ms/step - loss: 3.9282 - accuracy: 0.9635 - val_loss: 3.6585 - val_accuracy: 0.9770
# Epoch 7/50
# 63/63 [==============================] - 12s 181ms/step - loss: 3.7059 - accuracy: 0.9655 - val_loss: 9.0138 - val_accuracy: 0.9570
# Epoch 8/50
# 63/63 [==============================] - 12s 184ms/step - loss: 3.3729 - accuracy: 0.9705 - val_loss: 4.1123 - val_accuracy: 0.9770
# Epoch 9/50
# 63/63 [==============================] - 12s 186ms/step - loss: 2.9498 - accuracy: 0.9745 - val_loss: 3.0589 - val_accuracy: 0.9750
# Epoch 10/50
# 63/63 [==============================] - 12s 184ms/step - loss: 2.4965 - accuracy: 0.9695 - val_loss: 5.1444 - val_accuracy: 0.9660
# Epoch 11/50
# 63/63 [==============================] - 12s 183ms/step - loss: 2.6208 - accuracy: 0.9735 - val_loss: 3.7610 - val_accuracy: 0.9770
# Epoch 12/50
# 63/63 [==============================] - 12s 179ms/step - loss: 1.8162 - accuracy: 0.9830 - val_loss: 3.2889 - val_accuracy: 0.9810
# Epoch 13/50
# 63/63 [==============================] - 12s 185ms/step - loss: 2.0958 - accuracy: 0.9760 - val_loss: 2.6946 - val_accuracy: 0.9800
# Epoch 14/50
# 63/63 [==============================] - 12s 186ms/step - loss: 2.2246 - accuracy: 0.9800 - val_loss: 3.1666 - val_accuracy: 0.9770
# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **Freezing all layers until the fourth from the last**

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %% [markdown]
# **Fine-tuning the model**

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 15s 206ms/step - loss: 0.2078 - accuracy: 0.9945 - val_loss: 2.4652 - val_accuracy: 0.9800
# Epoch 2/30
# 63/63 [==============================] - 13s 203ms/step - loss: 0.5409 - accuracy: 0.9895 - val_loss: 2.1734 - val_accuracy: 0.9770
# Epoch 3/30
# 63/63 [==============================] - 13s 204ms/step - loss: 0.4156 - accuracy: 0.9920 - val_loss: 2.1626 - val_accuracy: 0.9760
# Epoch 4/30
# 63/63 [==============================] - 13s 203ms/step - loss: 0.3420 - accuracy: 0.9905 - val_loss: 1.9330 - val_accuracy: 0.9820
# Epoch 5/30
# 63/63 [==============================] - 13s 203ms/step - loss: 0.4301 - accuracy: 0.9900 - val_loss: 1.7627 - val_accuracy: 0.9840
# Epoch 6/30
# 63/63 [==============================] - 13s 202ms/step - loss: 0.2264 - accuracy: 0.9930 - val_loss: 1.6324 - val_accuracy: 0.9840
# Epoch 7/30
# 63/63 [==============================] - 13s 204ms/step - loss: 0.1678 - accuracy: 0.9940 - val_loss: 1.3439 - val_accuracy: 0.9820
# Epoch 8/30
# 63/63 [==============================] - 13s 203ms/step - loss: 0.3229 - accuracy: 0.9920 - val_loss: 2.1290 - val_accuracy: 0.9800
# Epoch 9/30
# 63/63 [==============================] - 13s 198ms/step - loss: 0.3146 - accuracy: 0.9915 - val_loss: 1.5054 - val_accuracy: 0.9810
# Epoch 10/30
# 63/63 [==============================] - 13s 198ms/step - loss: 0.1780 - accuracy: 0.9940 - val_loss: 1.4210 - val_accuracy: 0.9790
# Epoch 11/30
# 63/63 [==============================] - 13s 199ms/step - loss: 0.1552 - accuracy: 0.9945 - val_loss: 1.5266 - val_accuracy: 0.9840
# Epoch 12/30
# 63/63 [==============================] - 13s 202ms/step - loss: 0.1229 - accuracy: 0.9950 - val_loss: 1.8926 - val_accuracy: 0.9750
# Epoch 13/30
# 63/63 [==============================] - 13s 198ms/step - loss: 0.2234 - accuracy: 0.9930 - val_loss: 1.4758 - val_accuracy: 0.9800
# Epoch 14/30
# 63/63 [==============================] - 13s 199ms/step - loss: 0.2720 - accuracy: 0.9940 - val_loss: 1.8598 - val_accuracy: 0.9820
# Epoch 15/30
# 63/63 [==============================] - 13s 200ms/step - loss: 0.2009 - accuracy: 0.9925 - val_loss: 1.3472 - val_accuracy: 0.9820
# Epoch 16/30
# 63/63 [==============================] - 13s 203ms/step - loss: 0.1966 - accuracy: 0.9945 - val_loss: 1.9580 - val_accuracy: 0.9810
# Epoch 17/30
# 63/63 [==============================] - 13s 200ms/step - loss: 0.2019 - accuracy: 0.9935 - val_loss: 1.5957 - val_accuracy: 0.9800
# Epoch 18/30
# 63/63 [==============================] - 13s 196ms/step - loss: 0.1167 - accuracy: 0.9965 - val_loss: 1.6403 - val_accuracy: 0.9820
# Epoch 19/30
# 63/63 [==============================] - 13s 198ms/step - loss: 0.2708 - accuracy: 0.9930 - val_loss: 1.7440 - val_accuracy: 0.9800
# Epoch 20/30
# 63/63 [==============================] - 13s 201ms/step - loss: 0.1402 - accuracy: 0.9945 - val_loss: 2.5777 - val_accuracy: 0.9720
# Epoch 21/30
# 63/63 [==============================] - 13s 202ms/step - loss: 0.0606 - accuracy: 0.9975 - val_loss: 1.3206 - val_accuracy: 0.9820
# Epoch 22/30
# 63/63 [==============================] - 13s 201ms/step - loss: 0.2203 - accuracy: 0.9930 - val_loss: 1.4273 - val_accuracy: 0.9830
# Epoch 23/30
# 63/63 [==============================] - 13s 198ms/step - loss: 0.0730 - accuracy: 0.9950 - val_loss: 1.4974 - val_accuracy: 0.9820
# Epoch 24/30
# 63/63 [==============================] - 13s 199ms/step - loss: 0.1547 - accuracy: 0.9960 - val_loss: 1.4575 - val_accuracy: 0.9820
# Epoch 25/30
# 63/63 [==============================] - 13s 202ms/step - loss: 0.2015 - accuracy: 0.9945 - val_loss: 1.5382 - val_accuracy: 0.9810
# Epoch 26/30
# 63/63 [==============================] - 13s 198ms/step - loss: 0.1044 - accuracy: 0.9965 - val_loss: 1.6081 - val_accuracy: 0.9780
# Epoch 27/30
# 63/63 [==============================] - 13s 198ms/step - loss: 0.0848 - accuracy: 0.9955 - val_loss: 1.7550 - val_accuracy: 0.9830
# Epoch 28/30
# 63/63 [==============================] - 13s 202ms/step - loss: 0.1001 - accuracy: 0.9960 - val_loss: 1.5131 - val_accuracy: 0.9820
# Epoch 29/30
# 63/63 [==============================] - 13s 198ms/step - loss: 0.0793 - accuracy: 0.9975 - val_loss: 1.5321 - val_accuracy: 0.9820
# Epoch 30/30
# 63/63 [==============================] - 13s 203ms/step - loss: 0.0380 - accuracy: 0.9980 - val_loss: 1.2468 - val_accuracy: 0.9820

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 8s 118ms/step - loss: 1.4354 - accuracy: 0.9770
# Test accuracy: 0.977

# %% [markdown]
# ## Summary
